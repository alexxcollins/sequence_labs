# %% [markdown]
# # Extract frames from .mpg files
#
# This does the same as the python script.
#
# Currently it splits up ALL the movie files into frames, so uses the whole data set.
#
# videos are grouped into 25 groups with similarities within group so groups cannot be split across test/train/split. File name is of format `v_[category]_[group]_[numnber within group]`, so split by group number into test/train/split. See [UCF11](https://www.crcv.ucf.edu/data/UCF_YouTube_Action.php) for more details.

# %%
from pathlib import Path
import os

# %%
import os
from pathlib import Path

# this assumes you are in the working directory for Lecture7, and the videos are stored in directory UCF11_updated_mpg 

main_source_dir = Path('../data/lab6/ucf11_combined')
# this sorts all files except files starting with '.' - e.g. .ipynb_checkpoints
source_data = sorted(main_source_dir.glob('[!.]*'))
target_data = Path('../data/lab6')

##### from ffmpeg docs:
# ffmpeg -i movie.mpg movie%d.jpg
# https://ffmpeg.org/faq.html#How-do-I-encode-movie-to-single-pictures_003f
#####

train = []
test = []
val = []
for d in source_data:
    # ignore .ipynb_checkpoint folder. Don't need to sort in a special way.
    all_vids = sorted(d.glob('[!.]*'))
    # videos are grouped into 25 groups with similarities within group.
    # so groups cannot be split across test/train/split. File name is of format
    # v_[category]_[group]_[numnber within group], so split by group number
    # into test/train/split
    for vid in all_vids:
        group = int(vid.stem.split('_')[-2])
        if group < 16:
            train.append(vid)
        elif group >15 and group <21:
            test.append(vid)
        elif group >20:
            val.append(vid)

# iterate through test/train/split, split vids into frames and save in
# test/train/val folder. Eech video has its own directory.
for test_set, set_str in (#(train, 'train'), 
    (test, 'test'), (val, 'val')):
    for vid in test_set:
        p = target_data/('ucf11_' + set_str + '_data')
        p = p/vid.stem
        p.mkdir(exist_ok=True)
        os.system("ffmpeg -i {:} {:}/%05d.jpg".format(str(vid), str(p)))
# Out:
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mpeg, from '../data/lab6/ucf11_combined/basketball/v_shooting_16_01.mpg':
#   Duration: 00:00:15.72, start: 0.500000, bitrate: 896 kb/s
#     Stream #0:0[0x1e0]: Video: mpeg1video, yuv420p(tv), 320x240 [SAR 1:1 DAR 4:3], 104857 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 29.97 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg1video (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x148068000] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '../data/lab6/ucf11_test_data/v_shooting_16_01/%05d.jpg':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 320x240 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn, 29.97 tbc
#     Metadata:
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  471 fps=0.0 q=24.8 Lsize=N/A time=00:00:15.71 bitrate=N/A speed=53.3x
# video:2223kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mpeg, from '../data/lab6/ucf11_combined/basketball/v_shooting_16_02.mpg':
#   Duration: 00:00:11.54, start: 0.500000, bitrate: 1003 kb/s
#     Stream #0:0[0x1e0]: Video: mpeg1video, yuv420p(tv), 320x240 [SAR 1:1 DAR 4:3], 104857 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 29.97 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg1video (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x128008000] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '../data/lab6/ucf11_test_data/v_shooting_16_02/%05d.jpg':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 320x240 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn, 29.97 tbc
#     Metadata:
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  346 fps=0.0 q=24.8 Lsize=N/A time=00:00:11.54 bitrate=N/A speed=  53x
# video:1689kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mpeg, from '../data/lab6/ucf11_combined/basketball/v_shooting_16_03.mpg':
#   Duration: 00:00:17.55, start: 0.500000, bitrate: 947 kb/s
#     Stream #0:0[0x1e0]: Video: mpeg1video, yuv420p(tv), 320x240 [SAR 1:1 DAR 4:3], 104857 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 29.97 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg1video (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x148068000] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '../data/lab6/ucf11_test_data/v_shooting_16_03/%05d.jpg':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 320x240 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn, 29.97 tbc
#     Metadata:
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  528 fps=0.0 q=24.8 Lsize=N/A time=00:00:17.61 bitrate=N/A speed=52.9x
# video:2506kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mpeg, from '../data/lab6/ucf11_combined/basketball/v_shooting_16_04.mpg':
#   Duration: 00:00:17.28, start: 0.500000, bitrate: 913 kb/s
#     Stream #0:0[0x1e0]: Video: mpeg1video, yuv420p(tv), 320x240 [SAR 1:1 DAR 4:3], 104857 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 29.97 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg1video (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x138008000] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '../data/lab6/ucf11_test_data/v_shooting_16_04/%05d.jpg':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 320x240 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn, 29.97 tbc
#     Metadata:
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  518 fps=0.0 q=24.8 Lsize=N/A time=00:00:17.28 bitrate=N/A speed=55.9x
# video:2365kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mpeg, from '../data/lab6/ucf11_combined/basketball/v_shooting_16_05.mpg':
#   Duration: 00:00:00.33, start: 0.500000, bitrate: 1473 kb/s
#     Stream #0:0[0x1e0]: Video: mpeg1video, yuv420p(tv), 320x240 [SAR 1:1 DAR 4:3], 104857 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 29.97 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg1video (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x138068000] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '../data/lab6/ucf11_test_data/v_shooting_16_05/%05d.jpg':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 320x240 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn, 29.97 tbc
#     Metadata:
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=   13 fps=0.0 q=24.8 Lsize=N/A time=00:00:00.43 bitrate=N/A speed=39.4x
# video:146kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mpeg, from '../data/lab6/ucf11_combined/basketball/v_shooting_16_06.mpg':
#   Duration: 00:00:04.37, start: 0.500000, bitrate: 727 kb/s
#     Stream #0:0[0x1e0]: Video: mpeg1video, yuv420p(tv), 320x240 [SAR 1:1 DAR 4:3], 104857 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 29.97 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg1video (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x130008000] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '../data/lab6/ucf11_test_data/v_shooting_16_06/%05d.jpg':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 320x240 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn, 29.97 tbc
#     Metadata:
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  131 fps=0.0 q=24.8 Lsize=N/A time=00:00:04.37 bitrate=N/A speed=54.9x
# video:612kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mpeg, from '../data/lab6/ucf11_combined/basketball/v_shooting_16_07.mpg':
#   Duration: 00:00:03.20, start: 0.500000, bitrate: 828 kb/s
#     Stream #0:0[0x1e0]: Video: mpeg1video, yuv420p(tv), 320x240 [SAR 1:1 DAR 4:3], 104857 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 29.97 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg1video (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x118008000] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '../data/lab6/ucf11_test_data/v_shooting_16_07/%05d.jpg':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 320x240 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn, 29.97 tbc
#     Metadata:
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=   96 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.20 bitrate=N/A speed=54.7x
# video:520kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mpeg, from '../data/lab6/ucf11_combined/basketball/v_shooting_17_01.mpg':
#   Duration: 00:00:07.14, start: 0.500000, bitrate: 819 kb/s
#     Stream #0:0[0x1e0]: Video: mpeg1video, yuv420p(tv), 320x240 [SAR 1:1 DAR 4:3], 104857 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 29.97 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg1video (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x118008000] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '../data/lab6/ucf11_test_data/v_shooting_17_01/%05d.jpg':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 320x240 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn, 29.97 tbc
#     Metadata:
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  214 fps=0.0 q=24.8 Lsize=N/A time=00:00:07.14 bitrate=N/A speed=58.5x
# video:740kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mpeg, from '../data/lab6/ucf11_combined/basketball/v_shooting_17_02.mpg':
#   Duration: 00:00:02.80, start: 0.500000, bitrate: 666 kb/s
#     Stream #0:0[0x1e0]: Video: mpeg1video, yuv420p(tv), 320x214 [SAR 1:1 DAR 160:107], 104857 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 29.97 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg1video (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x128068000] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '../data/lab6/ucf11_test_data/v_shooting_17_02/%05d.jpg':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 320x214 [SAR 1:1 DAR 160:107], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn, 29.97 tbc
#     Metadata:
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=   84 fps=0.0 q=24.8 Lsize=N/A time=00:00:02.80 bitrate=N/A speed=  65x
# video:260kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mpeg, from '../data/lab6/ucf11_combined/basketball/v_shooting_17_03.mpg':
#   Duration: 00:00:05.07, start: 0.500000, bitrate: 516 kb/s
#     Stream #0:0[0x1e0]: Video: mpeg1video, yuv420p(tv), 320x214 [SAR 1:1 DAR 160:107], 104857 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 29.97 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg1video (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x138008000] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '../data/lab6/ucf11_test_data/v_shooting_17_03/%05d.jpg':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 320x214 [SAR 1:1 DAR 160:107], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn, 29.97 tbc
#     Metadata:
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  153 fps=0.0 q=24.8 Lsize=N/A time=00:00:05.10 bitrate=N/A speed=68.1x
# video:359kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mpeg, from '../data/lab6/ucf11_combined/basketball/v_shooting_17_04.mpg':
#   Duration: 00:00:03.84, start: 0.500000, bitrate: 657 kb/s
#     Stream #0:0[0x1e0]: Video: mpeg1video, yuv420p(tv), 320x240 [SAR 1:1 DAR 4:3], 104857 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 29.97 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg1video (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x128008000] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '../data/lab6/ucf11_test_data/v_shooting_17_04/%05d.jpg':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 320x240 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn, 29.97 tbc
#     Metadata:
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  115 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.83 bitrate=N/A speed=53.6x
# video:467kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mpeg, from '../data/lab6/ucf11_combined/basketball/v_shooting_18_01.mpg':
#   Duration: 00:00:06.01, start: 0.500000, bitrate: 1200 kb/s
#     Stream #0:0[0x1e0]: Video: mpeg1video, yuv420p(tv), 320x240 [SAR 1:1 DAR 4:3], 104857 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 29.97 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg1video (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x150008000] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '../data/lab6/ucf11_test_data/v_shooting_18_01/%05d.jpg':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 320x240 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn, 29.97 tbc
#     Metadata:
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  180 fps=0.0 q=24.8 Lsize=N/A time=00:00:06.00 bitrate=N/A speed=53.1x
# video:898kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mpeg, from '../data/lab6/ucf11_combined/basketball/v_shooting_18_02.mpg':
#   Duration: 00:00:06.27, start: 0.500000, bitrate: 566 kb/s
#     Stream #0:0[0x1e0]: Video: mpeg1video, yuv420p(tv), 320x240 [SAR 1:1 DAR 4:3], 104857 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 29.97 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg1video (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x118008000] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '../data/lab6/ucf11_test_data/v_shooting_18_02/%05d.jpg':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 320x240 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn, 29.97 tbc
#     Metadata:
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  188 fps=0.0 q=24.8 Lsize=N/A time=00:00:06.27 bitrate=N/A speed=63.3x
# video:610kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mpeg, from '../data/lab6/ucf11_combined/basketball/v_shooting_18_03.mpg':
#   Duration: 00:00:04.87, start: 0.500000, bitrate: 706 kb/s
#     Stream #0:0[0x1e0]: Video: mpeg1video, yuv420p(tv), 320x240 [SAR 1:1 DAR 4:3], 104857 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 29.97 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg1video (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x128068000] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '../data/lab6/ucf11_test_data/v_shooting_18_03/%05d.jpg':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 320x240 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn, 29.97 tbc
#     Metadata:
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  146 fps=0.0 q=24.8 Lsize=N/A time=00:00:04.87 bitrate=N/A speed=60.2x
# video:530kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mpeg, from '../data/lab6/ucf11_combined/basketball/v_shooting_18_04.mpg':
#   Duration: 00:00:07.87, start: 0.500000, bitrate: 938 kb/s
#     Stream #0:0[0x1e0]: Video: mpeg1video, yuv420p(tv), 320x240 [SAR 1:1 DAR 4:3], 104857 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 29.97 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg1video (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x140050000] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '../data/lab6/ucf11_test_data/v_shooting_18_04/%05d.jpg':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 320x240 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn, 29.97 tbc
#     Metadata:
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  236 fps=0.0 q=24.8 Lsize=N/A time=00:00:07.87 bitrate=N/A speed=59.2x
# video:845kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mpeg, from '../data/lab6/ucf11_combined/basketball/v_shooting_18_05.mpg':
#   Duration: 00:00:03.40, start: 0.500000, bitrate: 1145 kb/s
#     Stream #0:0[0x1e0]: Video: mpeg1video, yuv420p(tv), 320x240 [SAR 1:1 DAR 4:3], 104857 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 29.97 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg1video (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x138068000] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '../data/lab6/ucf11_test_data/v_shooting_18_05/%05d.jpg':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 320x240 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn, 29.97 tbc
#     Metadata:
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  102 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.40 bitrate=N/A speed=  53x
# video:449kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mpeg, from '../data/lab6/ucf11_combined/basketball/v_shooting_19_01.mpg':
#   Duration: 00:00:03.94, start: 0.500000, bitrate: 620 kb/s
#     Stream #0:0[0x1e0]: Video: mpeg1video, yuv420p(tv), 320x240 [SAR 1:1 DAR 4:3], 104857 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 29.97 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg1video (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x110008000] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '../data/lab6/ucf11_test_data/v_shooting_19_01/%05d.jpg':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 320x240 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn, 29.97 tbc
#     Metadata:
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  118 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.93 bitrate=N/A speed=62.9x
# video:328kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mpeg, from '../data/lab6/ucf11_combined/basketball/v_shooting_19_02.mpg':
#   Duration: 00:00:05.04, start: 0.500000, bitrate: 585 kb/s
#     Stream #0:0[0x1e0]: Video: mpeg1video, yuv420p(tv), 320x240 [SAR 1:1 DAR 4:3], 104857 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 29.97 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg1video (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x130068000] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '../data/lab6/ucf11_test_data/v_shooting_19_02/%05d.jpg':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 320x240 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn, 29.97 tbc
#     Metadata:
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  151 fps=0.0 q=24.8 Lsize=N/A time=00:00:05.03 bitrate=N/A speed=64.4x
# video:411kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mpeg, from '../data/lab6/ucf11_combined/basketball/v_shooting_19_03.mpg':
#   Duration: 00:00:03.34, start: 0.500000, bitrate: 677 kb/s
#     Stream #0:0[0x1e0]: Video: mpeg1video, yuv420p(tv), 320x240 [SAR 1:1 DAR 4:3], 104857 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 29.97 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg1video (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x150068000] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '../data/lab6/ucf11_test_data/v_shooting_19_03/%05d.jpg':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 320x240 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn, 29.97 tbc
#     Metadata:
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  101 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.37 bitrate=N/A speed=59.7x
# video:312kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mpeg, from '../data/lab6/ucf11_combined/basketball/v_shooting_19_04.mpg':
#   Duration: 00:00:04.57, start: 0.500000, bitrate: 659 kb/s
#     Stream #0:0[0x1e0]: Video: mpeg1video, yuv420p(tv), 320x240 [SAR 1:1 DAR 4:3], 104857 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 29.97 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg1video (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# ...
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mpeg, from '../data/lab6/ucf11_combined/walking/v_walk_dog_24_04.mpg':
#   Duration: 00:00:07.97, start: 0.500000, bitrate: 756 kb/s
#     Stream #0:0[0x1e0]: Video: mpeg1video, yuv420p(tv), 320x256 [SAR 1:1 DAR 5:4], 104857 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 29.97 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg1video (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x128068000] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '../data/lab6/ucf11_val_data/v_walk_dog_24_04/%05d.jpg':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 320x256 [SAR 1:1 DAR 5:4], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn, 29.97 tbc
#     Metadata:
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  240 fps=0.0 q=24.8 Lsize=N/A time=00:00:08.00 bitrate=N/A speed=  58x
# video:562kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mpeg, from '../data/lab6/ucf11_combined/walking/v_walk_dog_24_05.mpg':
#   Duration: 00:00:08.01, start: 0.500000, bitrate: 1008 kb/s
#     Stream #0:0[0x1e0]: Video: mpeg1video, yuv420p(tv), 320x256 [SAR 1:1 DAR 5:4], 104857 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 29.97 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg1video (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x120008000] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '../data/lab6/ucf11_val_data/v_walk_dog_24_05/%05d.jpg':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 320x256 [SAR 1:1 DAR 5:4], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn, 29.97 tbc
#     Metadata:
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  240 fps=0.0 q=24.8 Lsize=N/A time=00:00:08.00 bitrate=N/A speed=58.1x
# video:611kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mpeg, from '../data/lab6/ucf11_combined/walking/v_walk_dog_24_06.mpg':
#   Duration: 00:00:07.97, start: 0.500000, bitrate: 1000 kb/s
#     Stream #0:0[0x1e0]: Video: mpeg1video, yuv420p(tv), 320x256 [SAR 1:1 DAR 5:4], 104857 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 29.97 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg1video (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x128008000] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '../data/lab6/ucf11_val_data/v_walk_dog_24_06/%05d.jpg':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 320x256 [SAR 1:1 DAR 5:4], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn, 29.97 tbc
#     Metadata:
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  240 fps=0.0 q=24.8 Lsize=N/A time=00:00:08.00 bitrate=N/A speed=58.5x
# video:617kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mpeg, from '../data/lab6/ucf11_combined/walking/v_walk_dog_25_01.mpg':
#   Duration: 00:00:07.97, start: 0.500000, bitrate: 984 kb/s
#     Stream #0:0[0x1e0]: Video: mpeg1video, yuv420p(tv), 320x240 [SAR 1:1 DAR 4:3], 104857 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 29.97 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg1video (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x140068000] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '../data/lab6/ucf11_val_data/v_walk_dog_25_01/%05d.jpg':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 320x240 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn, 29.97 tbc
#     Metadata:
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  240 fps=0.0 q=24.8 Lsize=N/A time=00:00:08.00 bitrate=N/A speed=57.9x
# video:789kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mpeg, from '../data/lab6/ucf11_combined/walking/v_walk_dog_25_02.mpg':
#   Duration: 00:00:07.97, start: 0.500000, bitrate: 1197 kb/s
#     Stream #0:0[0x1e0]: Video: mpeg1video, yuv420p(tv), 320x240 [SAR 1:1 DAR 4:3], 104857 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 29.97 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg1video (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x140008000] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '../data/lab6/ucf11_val_data/v_walk_dog_25_02/%05d.jpg':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 320x240 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn, 29.97 tbc
#     Metadata:
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  240 fps=0.0 q=24.8 Lsize=N/A time=00:00:08.00 bitrate=N/A speed=55.7x
# video:792kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mpeg, from '../data/lab6/ucf11_combined/walking/v_walk_dog_25_03.mpg':
#   Duration: 00:00:07.97, start: 0.500000, bitrate: 1175 kb/s
#     Stream #0:0[0x1e0]: Video: mpeg1video, yuv420p(tv), 320x240 [SAR 1:1 DAR 4:3], 104857 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 29.97 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg1video (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x140050000] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '../data/lab6/ucf11_val_data/v_walk_dog_25_03/%05d.jpg':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 320x240 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn, 29.97 tbc
#     Metadata:
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  240 fps=0.0 q=24.8 Lsize=N/A time=00:00:08.00 bitrate=N/A speed=54.7x
# video:815kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 11.1.0
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1634125573833/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mpeg, from '../data/lab6/ucf11_combined/walking/v_walk_dog_25_04.mpg':
#   Duration: 00:00:06.84, start: 0.500000, bitrate: 1065 kb/s
#     Stream #0:0[0x1e0]: Video: mpeg1video, yuv420p(tv), 320x240 [SAR 1:1 DAR 4:3], 104857 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 29.97 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg1video (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x120008000] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '../data/lab6/ucf11_val_data/v_walk_dog_25_04/%05d.jpg':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 320x240 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn, 29.97 tbc
#     Metadata:
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  205 fps=0.0 q=24.8 Lsize=N/A time=00:00:06.84 bitrate=N/A speed=58.7x
# video:577kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
for test_set, set_str in ((train, 'train'), (test, 'test'), (val, 'val')):
    print(test_set[0])
    print(set_str)
    print('\n')
# Out:
# ../data/lab6/ucf11_combined/basketball/v_shooting_01_01.mpg
# train
#
#
# ../data/lab6/ucf11_combined/basketball/v_shooting_16_01.mpg
# test
#
#
# ../data/lab6/ucf11_combined/basketball/v_shooting_21_01.mpg
# val
